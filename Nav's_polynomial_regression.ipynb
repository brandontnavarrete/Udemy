# %% [markdown]
# <a href="https://colab.research.google.com/github/brandontnavarrete/Udemy/blob/main/Nav's_polynomial_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
# Essential Imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
# read data in
dataset = pd.read_csv('Position_Salaries.csv')
# starting at column 2 and leave last one out
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
# import linear reg model
from sklearn.linear_model import LinearRegression
# model instance
lin_reg = LinearRegression()
# fit model on x and y  
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
# polynomial features from preprocessing
from sklearn.preprocessing import PolynomialFeatures
# selecting degree of n of the bnX1^n
poly_reg = PolynomialFeatures(degree = 4)

# fit and transform on features
X_poly = poly_reg.fit_transform(X)

# linear regression model fit on features and y
# incorporate X_poly in linear regression model.
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
# set actual values and color red
plt.scatter(X, y, color = 'red')

# plotting predictions
plt.plot(X, lin_reg.predict(X), color = 'blue')

plt.title('Truth or Bluff (Linear Regression)')

plt.xlabel('Position Level')

plt.ylabel('Salary')

plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
# plot actual values
plt.scatter(X, y, color = 'red')

# plot predictions from poly model
# actual x 
plt.plot(X, lin_reg_2.predict(poly_reg.fit_transform(X)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, lin_reg_2.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
lin_reg.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.45265155])
